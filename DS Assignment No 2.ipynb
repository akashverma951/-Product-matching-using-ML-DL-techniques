# %%
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns
import matplotlib.pyplot as pt
import warnings
warnings.filterwarnings('ignore')

# %%
df_a=pd.read_excel('/content/amz_com-ecommerce_sample.xlsx')
df_a
# Out:
#                                 uniq_id            crawl_timestamp  \
# 0      c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1      7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2      f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3      0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4      bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
# ...                                 ...                        ...
# 19995  7179d2f6c4ad50a17d014ca1d2815156  2015-12-01 10:15:43 +0000
# 19996  71ac419198359d37b8fe5e3fffdfee09  2015-12-01 10:15:43 +0000
# 19997  93e9d343837400ce0d7980874ece471c  2015-12-01 10:15:43 +0000
# 19998  669e79b8fa5d9ae020841c0c97d5e935  2015-12-01 10:15:43 +0000
# 19999  cb4fa87a874f715fff567f7b7b3be79c  2015-12-01 10:15:43 +0000
#
#                                              product_url  \
# 0      http://www.flipkart.com/alisha-solid-women-s-c...
# ...

# %%
df_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   uniq_id                  20000 non-null  object
#  1   crawl_timestamp          20000 non-null  object
#  2   product_url              20000 non-null  object
#  3   product_name             20000 non-null  object
#  4   product_category_tree    20000 non-null  object
#  5   pid                      20000 non-null  object
#  6   retail_price             20000 non-null  int64
#  7   discounted_price         20000 non-null  int64
#  8   image                    19997 non-null  object
#  9   is_FK_Advantage_product  20000 non-null  bool
#  10  description              19998 non-null  object
#  11  product_rating           20000 non-null  object
#  12  overall_rating           20000 non-null  object
#  13  brand                    14136 non-null  object
# ...

# %%
df_a.columns
# Out:
# Index(['uniq_id', 'crawl_timestamp', 'product_url', 'product_name',
#        'product_category_tree', 'pid', 'retail_price', 'discounted_price',
#        'image', 'is_FK_Advantage_product', 'description', 'product_rating',
#        'overall_rating', 'brand', 'product_specifications'],
#       dtype='object')

# %%
df_a.drop(['uniq_id','crawl_timestamp', 'product_url','product_category_tree',
            'image', 'is_FK_Advantage_product', 'description', 'product_rating',
       'overall_rating', 'brand', 'product_specifications'],axis=1,inplace=True)

# %%
df_f=pd.read_csv('flipkart_com-ecommerce_sample.csv')
df_f
# Out:
#                                 uniq_id            crawl_timestamp  \
# 0      c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1      7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2      f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3      0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4      bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
# ...                                 ...                        ...
# 19995  7179d2f6c4ad50a17d014ca1d2815156  2015-12-01 10:15:43 +0000
# 19996  71ac419198359d37b8fe5e3fffdfee09  2015-12-01 10:15:43 +0000
# 19997  93e9d343837400ce0d7980874ece471c  2015-12-01 10:15:43 +0000
# 19998  669e79b8fa5d9ae020841c0c97d5e935  2015-12-01 10:15:43 +0000
# 19999  cb4fa87a874f715fff567f7b7b3be79c  2015-12-01 10:15:43 +0000
#
#                                              product_url  \
# 0      http://www.flipkart.com/alisha-solid-women-s-c...
# ...

# %%
df_f.drop(['uniq_id','crawl_timestamp', 'product_url','product_category_tree',
            'image', 'is_FK_Advantage_product', 'description', 'product_rating',
       'overall_rating', 'brand', 'product_specifications'],axis=1,inplace=True)

# %%
df_a
# Out:
#                                   product_name               pid  \
# 0          Alisha Solid Women's Cycling Shorts  SRTEH2FF9KEDEFGF
# 1          FabHomeDecor Fabric Double Sofa Bed  SBEEH3QGU7MFYJFY
# 2                                   AW Bellies  SHOEH4GRSUBJGZXE
# 3          Alisha Solid Women's Cycling Shorts  SRTEH2F6HUZMQ6SJ
# 4        Sicons All Purpose Arnica Dog Shampoo  PSOEH3ZYDMSYARJ5
# ...                                        ...               ...
# 19995           WALLDESIGN SMALL VINYL STICKER  STIE7KFJAKSTDY9G
# 19996  WALLMANTRA LARGE VINYL STICKERS STICKER  STIE9F5URNQGJCGH
# 19997  ELITE COLLECTION MEDIUM ACRYLIC STICKER  STIE7VAYDKQZEBSD
# 19998  ELITE COLLECTION MEDIUM ACRYLIC STICKER  STIE8YSVEPPCZ42Y
# 19999  ELITE COLLECTION MEDIUM ACRYLIC STICKER  STIE88KN9ZDSGZKY
#
#        retail_price  discounted_price
# 0               982               438
# 1             32143             29121
# 2               991               551
# ...

# %%
df_f
# Out:
#                                   product_name               pid  \
# 0          Alisha Solid Women's Cycling Shorts  SRTEH2FF9KEDEFGF
# 1          FabHomeDecor Fabric Double Sofa Bed  SBEEH3QGU7MFYJFY
# 2                                   AW Bellies  SHOEH4GRSUBJGZXE
# 3          Alisha Solid Women's Cycling Shorts  SRTEH2F6HUZMQ6SJ
# 4        Sicons All Purpose Arnica Dog Shampoo  PSOEH3ZYDMSYARJ5
# ...                                        ...               ...
# 19995           WallDesign Small Vinyl Sticker  STIE7KFJAKSTDY9G
# 19996  Wallmantra Large Vinyl Stickers Sticker  STIE9F5URNQGJCGH
# 19997  Elite Collection Medium Acrylic Sticker  STIE7VAYDKQZEBSD
# 19998  Elite Collection Medium Acrylic Sticker  STIE8YSVEPPCZ42Y
# 19999  Elite Collection Medium Acrylic Sticker  STIE88KN9ZDSGZKY
#
#        retail_price  discounted_price
# 0             999.0             379.0
# 1           32157.0           22646.0
# 2             999.0             499.0
# ...

# %%
df1= pd.merge(df_a, df_f, on="pid")

# %%
df1.drop('pid',axis=1,inplace=True)

# %%
df1.rename(columns={'product_name_x': 'Product name in Amazon',
                    'retail_price_x': 'Retail price in amazon',
                     'discounted_price_x': 'Discounted price in amazon',
                    'product_name_y': 'Product name in Flipcart',
                    'retail_price_y': 'Retail price in Flipcart',
                     'discounted_price_y': 'Discounted price in Flipcart',})
# Out:
#                         Product name in Amazon  Retail price in amazon  \
# 0          Alisha Solid Women's Cycling Shorts                     982
# 1          FabHomeDecor Fabric Double Sofa Bed                   32143
# 2                                   AW Bellies                     991
# 3          Alisha Solid Women's Cycling Shorts                     694
# 4        Sicons All Purpose Arnica Dog Shampoo                     208
# ...                                        ...                     ...
# 19999           WALLDESIGN SMALL VINYL STICKER                    1498
# 20000  WALLMANTRA LARGE VINYL STICKERS STICKER                    1415
# 20001  ELITE COLLECTION MEDIUM ACRYLIC STICKER                    1284
# 20002  ELITE COLLECTION MEDIUM ACRYLIC STICKER                    1492
# 20003  ELITE COLLECTION MEDIUM ACRYLIC STICKER                    1484
#
#        Discounted price in amazon                 Product name in Flipcart  \
# ...
